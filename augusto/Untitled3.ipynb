# %%
using Jacobi
using PyPlot

# %%
Q = 4
#z = zglj(Q);
z = linspace(-1,1,Q)
for i in 1:Q
    x = linspace(-1,1,101);
    y = lagrange(i,x,z);
    plot(x,y,label="$i")
end
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6e7800d7d0>)
# PyObject <matplotlib.legend.Legend object at 0x7f6e77a9f750>

# %%
collect(z)
# Out:
# 4-element Array{Float64,1}:
#  -1.0
#  -0.333333
#   0.333333
#   1.0

# %%
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcebc056190>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcea1ff9690>
