# %%
using Interact, PyPlot

f = figure()
@manipulate for n in 1:10, m in 1:10 withfig(f) do
      ts = linspace(0, 2*n*m*pi, 2500)
      xs = [sin(m*t) for t in ts]
      ys = [cos(n*t) for t in ts]
      PyPlot.plot(xs, ys)
    end
end
# Out:
# Interact.Slider{Int64}(Signal{Int64}(5, nactions=0),"n",5,1:10,true)
# Interact.Slider{Int64}(Signal{Int64}(5, nactions=0),"m",5,1:10,true)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4aff7e4790>)
