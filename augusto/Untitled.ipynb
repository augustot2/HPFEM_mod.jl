# %%
using PyPlot

# %%
f(x) = 3*x - 3
f(x)
# Out:
# 100-element Array{Float64,1}:
#  -1.0
#  -0.989899
#  -0.979798
#  -0.969697
#  -0.959596
#  -0.949495
#  -0.939394
#  -0.929293
#  -0.919192
#  -0.909091
#  -0.89899
#  -0.888889
#  -0.878788
#   ⋮
#  -0.111111
#  -0.10101
#  -0.0909091
#  -0.0808081
#  -0.0707071
#  -0.0606061
#  -0.0505051
#  -0.040404
#  -0.030303
#  -0.020202
#  -0.010101
#   0.0

# %%
x = collect(linspace(2/3,1,100))
plot(x,f(x))
f(x)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f1b155d1090>)
# 100-element Array{Float64,1}:
#  1.0
#  1.00505
#  1.0101
#  1.01515
#  1.0202
#  1.02525
#  1.0303
#  1.03535
#  1.0404
#  1.04545
#  1.05051
#  1.05556
#  1.06061
#  ⋮
#  1.44444
#  1.44949
#  1.45455
#  1.4596
#  1.46465
#  1.4697
#  1.47475
#  1.4798
#  1.48485
#  1.4899
#  1.49495
#  1.5
